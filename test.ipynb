# %%
import pandas as pd

# %%
df = pd.read_csv(r"e:\24_1_Juli_dataset\Detection.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15762 entries, 0 to 15761
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Model              15762 non-null  object
#  1   Path Gambar        15762 non-null  object
#  2   Nama File          15762 non-null  object
#  3   Jumlah Objek       15762 non-null  int64
#  4   Kelas Unik         15762 non-null  object
#  5   Kelas Dominan      15762 non-null  object
#  6   Label YOLO Format  15762 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 862.1+ KB

# %%
df = df[df['Jumlah Objek']>24]

# %%
df
# Out:
#         Model                                        Path Gambar  \
# 29     Innova  E:\24_1_Juli_dataset\2025-07-01_11-09-25\CAMER...
# 35     Innova  E:\24_1_Juli_dataset\2025-07-01_11-09-15\CAMER...
# 41     Innova  E:\24_1_Juli_dataset\2025-07-01_11-09-02\CAMER...
# 66     Innova  E:\24_1_Juli_dataset\2025-07-01_11-04-07\CAMER...
# 132    Innova  E:\24_1_Juli_dataset\2025-07-01_10-44-06\CAMER...
# ...       ...                                                ...
# 15526  Innova  E:\24_1_Juli_dataset\2025-06-24_01-40-57\CAMER...
# 15611  Innova  E:\24_1_Juli_dataset\2025-06-24_01-17-35\CAMER...
# 15669  Innova  E:\24_1_Juli_dataset\2025-06-24_00-56-56\CAMER...
# 15675  Innova  E:\24_1_Juli_dataset\2025-06-24_00-56-41\CAMER...
# 15741  Innova  E:\24_1_Juli_dataset\2025-06-24_00-36-39\CAMER...
#
#           Nama File  Jumlah Objek  \
# 29     CAMERA_1.jpg            26
# 35     CAMERA_1.jpg            26
# 41     CAMERA_1.jpg            26
# 66     CAMERA_1.jpg            26
# ...
